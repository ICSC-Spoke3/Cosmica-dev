# %%
from os.path import join as pjoin, dirname, basename
from files_utils import *
from physics_utils import *
from isotopes import *

# %%
z, a, t0, _ = ISOTOPES['Proton']
z, a, t0
# Out:
# (1.0, 1.0, 0.938272)

# %%
ROOTDIR = '/Users/stark/Development/Research/Cosmica-dev/extra/simfiles'
plis = pjoin(ROOTDIR, 'GALPROP_LIS_Esempio')

# %%
lis = load_lis(plis)

# %%
get_lis(lis, z, a)
# Out:
# (array([1.00000000e-03, 1.10118435e-03, 1.21260697e-03, 1.33530382e-03,
#         1.47041567e-03, 1.61919873e-03, 1.78303630e-03, 1.96345167e-03,
#         2.16212225e-03, 2.38089519e-03, 2.62180452e-03, 2.88709011e-03,
#         3.17921845e-03, 3.50090560e-03, 3.85514246e-03, 4.24522255e-03,
#         4.67477264e-03, 5.14778647e-03, 5.66866190e-03, 6.24224177e-03,
#         6.87385895e-03, 7.56938591e-03, 8.33528930e-03, 9.17869014e-03,
#         1.01074299e-02, 1.11301437e-02, 1.22563400e-02, 1.34964898e-02,
#         1.48621234e-02, 1.63659377e-02, 1.80219145e-02, 1.98454502e-02,
#         2.18534992e-02, 2.40647313e-02, 2.64997055e-02, 2.91810610e-02,
#         3.21337277e-02, 3.53851581e-02, 3.89655823e-02, 4.29082895e-02,
#         4.72499369e-02, 5.20308911e-02, 5.72956030e-02, 6.30930214e-02,
#         6.94770478e-02, 7.65070377e-02, 8.42483527e-02, 9.27729675e-02,
#         1.02160140e-01, 1.12497147e-01, 1.23880098e-01, 1.36414826e-01,
# ...

# %%
get_lis(lis, z, a, rig=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_lis(lis, z, a, rig=True)
#
# File ~/Development/Research/Cosmica-dev/Cosmica_V8-speedtest/scripts/evaluate/physics_utils.py:334, in get_lis(lis, z, a, k, include_secondaries, rig, debug)
#     331 if rig:
#     332     tk_bin, particle_flux = en_to_rig_flux(*lis, a, z)
# --> 334 tk_lis_spectra = particle_flux[z][a][k][-1]  # the primary spectrum is always the last one (if exist)
#     335 if include_secondaries:  # Include (sum) secondary spectra
#     336     for sec_ind in range(len(particle_flux[z][a][k]) - 1):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
