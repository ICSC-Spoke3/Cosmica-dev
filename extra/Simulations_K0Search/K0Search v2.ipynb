# %%
# %load_ext autoreload
# %autoreload 2

# -*- coding: utf-8 -*-
# Developed: Aug 2023
# Last update: Dec 2023
'''
Procedure for K0 search.
'''

import os
import shutil
import datetime as dt
import time
import glob
import numpy as np
import pickle
from JobCreation import Load_HeliosphericParameters, griglia_valori_k0, SubmitSims
from EvaluateSimAndFlux import GetRawMatrix, EvaluateFlux

DEBUG = True
NK0 = 400  #Number of K0 to test
SLEEP_TIME = 60
APP = "_FD006"
OUTPUT_DICT = {}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_simulation_list(app_name, debug=False):
    """
        Load the list of simulations.

        Parameters:
        app_name (str): the application name.
        debug (bool): whether to print debug information.

        Returns:
        sim_list (list): the list of simulations.
    """

    # Counters for excluded simulations (Added by me)
    excluded_sims_filter = 0
    excluded_sims_type = 0

    sim_list = []
    if debug:
        print(f"Loading simulations for application: {app_name}")

    for line in open(f"Simulations{app_name}.list").readlines():
        if line.startswith("#"):
            continue

        single_sim = [x.strip() for x in line.replace("\t", "").split("|")[:8]]
        if debug:
            print(f"Parsed simulation: {single_sim}")

        # if debug is true, it excludes all files obtaining a final empty list, so I inibited it (MG)
        # if debug:
        if False:
            if (float(single_sim[3]) < 20180101 or float(single_sim[3]) > 20180102):
                excluded_sims_filter += 1
            continue

        if "Electron" in single_sim[1] or "Positron" in single_sim[1]:
            if debug:
                excluded_sims_type += 1
            continue

        print(f"Adding simulation: {single_sim}")
        sim_list.append(single_sim)

        ions = single_sim[1].strip()
        if ions not in OUTPUT_DICT:
            OUTPUT_DICT[ions] = {}
            if debug:
                print(f"Added new ion type to OUTPUT_DICT: {ions}")

    if debug:
        print(f"Loaded simulation list:")
        for sim in sim_list:
            print(sim)
        print(f"Ecluded simulations due to filter: {excluded_sims_filter}")
        print(f"Ecluded simulations due to particle type: {excluded_sims_type}")

    return sim_list

# %%
def initialize_output_dict(sim_list, x_exp, f_exp, er_exp_inf, er_exp_sup, k0_ref, k0_ref_err, debug=False):
    """
        Initialize the output dictionary with experimental data.

        Parameters:
        sim_list (list): the list of simulations.
        x_exp (np.array): the experimental rigidity values.
        f_exp (np.array): the experimental flux values.
        er_exp_inf (np.array): the experimental flux lower error values.
        er_exp_sup (np.array): the experimental flux upper error values.
        k0_ref (float): the reference K0 value.
        k0_ref_err (float): the reference K0 error value.
        debug (bool): whether to print debug information.

        Returns:
        None
    """

    # debug = True

    for el in sim_list:
        ions = el[1].strip()
        time = dt.datetime.strptime(el[3], '%Y%m%d').date()
        if debug:
            print(f"Processing simulation for ion: {ions}, date: {time}")

        # For each rigidity value in the experimental data (in the range [3, 11])
        for i, T in enumerate(x_exp):
            if not (3 <= T <= 11):
                continue

            if debug:
                print(f"Processing rigidity value: {T}")

            # Initialize the output dictionary
            if T not in OUTPUT_DICT[ions]:
                OUTPUT_DICT[ions][T] = {}
                if debug:
                    print(f"Initialized OUTPUT_DICT for ion: {ions}, rigidity: {T}")

            # Initialize the output dictionary for the current ion and rigidity value
            OUTPUT_DICT[ions][T][time] = {
                "diffBest": 9e99,
                "K0best": 0,
                "K0Min": 9e99,
                "K0Max": 0,
                "Fluxbest": 0,
                "FluxMin": 9e99,
                "FluxMax": 0,
                "fExp": f_exp[i],
                "ErExp_inf": er_exp_inf[i],
                "ErExp_sup": er_exp_sup[i],
                "K0ref": k0_ref,
                "K0Err_ref": k0_ref_err * k0_ref,
            }
            if debug:
                print(f"Initialized data for ion: {ions}, rigidity: {T}, date: {time}")

    if debug:
        print("Final OUTPUT_DICT:")
        for ion, data in OUTPUT_DICT.items():
            print(f"Ion: {ion}, Data: {data}")

# %%
def wait_for_files(output_dir_path_name, n_files_expected, sleep_time, debug=False):
    """
        Wait until the expected number of output files is present.

        Parameters:
        output_dir_path_name (str): the path to the output directory.
        n_files_expected (int): the number of files expected.
        sleep_time (int): the time to sleep between checks.
        debug (bool): whether to print debug information.

        Returns:
        None
    """
    print(f"Waiting for {n_files_expected} files in {output_dir_path_name}...")
    while len(glob.glob(output_dir_path_name)) < n_files_expected:
        time.sleep(sleep_time)
        if debug:
            print(f"Found {len(glob.glob(output_dir_path_name))} files so far.")

# %%
def process_simulations(el_sim_list, raw_matrix_sims, x_exp, debug=False):
    """
        Process simulation results to find the best K0 values.

        Parameters:
        el_sim_list (list): the list of simulations.
        raw_matrix_sims (dict): the raw matrix of simulation results.
        x_exp (np.array): the experimental rigidity values.
        debug (bool): whether to print debug information.

        Returns:
        None
    """
    ions = el_sim_list[1].strip()
    time = dt.datetime.strptime(el_sim_list[3], '%Y%m%d').date()
    if debug:
        print(f"Processing simulations for ion: {ions}, date: {time}")

    fluxes = EvaluateFlux(el_sim_list, raw_matrix_sims, x_exp, debug)

    # For each K0 value and simulated flux value
    for k0, (sim_en_rig, sim_flux) in fluxes.items():
        if debug:
            print(f"Evaluating K0: {k0}")

        # For each rigidity value in the experimental data (in the range [3, 11])
        for i, F in enumerate(sim_flux):
            T = x_exp[i]
            if not (3 <= T <= 11):
                continue

            ref_entry = OUTPUT_DICT[ions][T][time]
            diff_val = F - ref_entry['fExp']
            if debug:
                print(
                    f"Rigidity: {T}, Simulated Flux: {F}, Experimental Flux: {ref_entry['fExp']}, Difference: {diff_val}")

            if -ref_entry['ErExp_inf'] <= diff_val <= ref_entry['ErExp_sup']:
                if debug:
                    print(
                        f"Difference {diff_val} is within error bounds [{-ref_entry['ErExp_inf']}, {ref_entry['ErExp_sup']}]")

                # If the difference is better than the current best difference, update the reference entry
                if abs(diff_val) < abs(ref_entry['diffBest']):
                    ref_entry['diffBest'] = diff_val
                    ref_entry['K0best'] = k0
                    ref_entry['Fluxbest'] = F
                    if debug:
                        print(f"Updated best values for ion: {ions}, rigidity: {T}, date: {time}")

                # If the K0 value is better than the current best K0 value, update the reference entry
                if ref_entry['K0Min'] > k0:
                    ref_entry['FluxMin'] = F
                    ref_entry['K0Min'] = k0
                    if debug:
                        print(f"Updated minimum K0 for ion: {ions}, rigidity: {T}, date: {time}")

                # If the K0 value is better than the current worst K0 value, update the reference entry
                if ref_entry['K0Max'] < k0:
                    ref_entry['FluxMax'] = F
                    ref_entry['K0Max'] = k0
                    if debug:
                        print(f"Updated maximum K0 for ion: {ions}, rigidity: {T}, date: {time}")

# %%
## Magic physics functions!


def smooth_transition(initial_val, final_val, center_of_transition, smoothness, x):
    # smooth transition between  InitialVal to FinalVal centered at CenterOfTransition as function of x
    # if smoothness== 0 use a sharp transition
    if smoothness == 0:
        return final_val if x >= center_of_transition else initial_val
    else:
        return (initial_val + final_val) / 2. - (initial_val - final_val) / 2. * np.tanh(
            (x - center_of_transition) / smoothness)


def k0_fit_ssn(p, solar_phase, ssn):
    if p > 0.:
        if solar_phase == 0:  # Rising
            k0 = 0.0002743 - 2.11e-6 * ssn + 1.486e-8 * ssn * ssn - 3.863e-11 * ssn * ssn * ssn;
            gauss_var = 0.1122
        else:  # Declining
            k0 = 0.0002787 - 1.66e-6 * ssn + 4.658e-9 * ssn * ssn - 6.673e-12 * ssn * ssn * ssn;
            gauss_var = 0.1324
    else:
        if solar_phase == 0:  # Rising
            k0 = 0.0003059 - 2.51e-6 * ssn + 1.284e-8 * ssn * ssn - 2.838e-11 * ssn * ssn * ssn;
            gauss_var = 0.1097
        else:  # Declining
            k0 = 0.0002876 - 3.715e-6 * ssn + 2.534e-8 * ssn * ssn - 5.689e-11 * ssn * ssn * ssn;
            gauss_var = 0.14
    return k0, gauss_var


def k0_fit_nmc(nmc):
    return np.exp(-10.83 - 0.0041 * nmc + 4.52e-5 * nmc * nmc), 0.1045


def k0_corr_factor(p, q, solar_phase, tilt):
    #   /*Authors: 2017 Stefano */
    #   /* * description: Correction factor to K0 for the Kparallel. This correction is introduced
    #                     to account for the fact that K0 is evaluated with a model not including particle drift.
    #                     Thus, the value need a correction once to be used in present model
    #       \param p            solar polarity of HMF
    #       \param q            signum of particle charge
    #       \param SolarPhase   0=rising / 1=Declining phase of solar activity cycle
    #       \param tilt         Tilt angle of neutral sheet (in degree)
    #   */
    k0_corr_maxv = 1.5
    k0_corr_minv = 1.
    k0_corr_p0_asc = 18.
    k0_corr_p1_asc = 40.
    k0_corr_p0_des = 5.
    k0_corr_p1_des = 53.
    k0_corr_maxv_neg = 0.7
    k0_corr_p0_asc_neg = 5.8
    k0_corr_p1_asc_neg = 47.
    k0_corr_p0_des_neg = 5.8
    k0_corr_p1_des_neg = 58.

    if q > 0:
        if q * p > 0:
            if solar_phase == 0:  # ascending
                return smooth_transition(k0_corr_maxv, k0_corr_minv, k0_corr_p1_asc, k0_corr_p0_asc, tilt)
            else:  # descending
                return smooth_transition(k0_corr_maxv, k0_corr_minv, k0_corr_p1_des, k0_corr_p0_des, tilt)
        else:
            return 1
    if q < 0:
        if q * p > 0:
            if solar_phase == 0:  # ascending
                return smooth_transition(k0_corr_maxv, k0_corr_minv, k0_corr_p1_asc, k0_corr_p0_asc, tilt)
            else:  # descending
                return smooth_transition(k0_corr_maxv, k0_corr_minv, k0_corr_p1_des, k0_corr_p0_des, tilt)
        else:
            if solar_phase == 0:  # ascending
                return smooth_transition(k0_corr_maxv_neg, k0_corr_minv, k0_corr_p1_asc_neg, k0_corr_p0_asc_neg, tilt)
            else:  # descending
                return smooth_transition(k0_corr_maxv_neg, k0_corr_minv, k0_corr_p1_des_neg, k0_corr_p0_des_neg, tilt)
    return 1


def eval_k0(is_high_activity_period, p, q, solar_phase, tilt, nmc, ssn):
    #   /*Authors: 2022 Stefano */
    #   /* * description: Evaluate diffusion parameter from fitting procedures.
    #       \param p            solar polarity of HMF
    #       \param q            signum of particle charge
    #       \param SolarPhase   0=rising / 1=Declining phase of solar activity cycle
    #       \param tilt         Tilt angle of neutral sheet (in degree)
    #       \return x = k0_paral
    #               y = k0_perp
    #               z = GaussVar
    #   */
    #   float3 output;
    k0cor = k0_corr_factor(p, q, solar_phase, tilt)  #; // k0_paral is corrected by a correction factor
    if is_high_activity_period and nmc > 0:
        k0, kerr = k0_fit_nmc(nmc)
    else:
        k0, kerr = k0_fit_ssn(p, solar_phase, ssn)
    return k0 * k0cor, kerr

# %%
def k0_grid(t: int, nk0: int, hpar: np.ndarray, q=+1, debug=False):
    """
        Generate a grid of K0 values.

        Parameters:
        t (int): the time step for each simulation.
        nk0 (int): the number of K0 values.
        heliospheric_parameters (list): the list of heliospheric parameters for each simulation.
        q (int): the sign of particle charge.
        debug (bool): whether to print debug information.

        Returns:
        k0grid (dict): the grid of K0 values.
        k0 (int): the reference k0 value.
        k0err (int): the error of the reference k0 value.
    """
    k0grid = np.ones(nk0)
    k0, k0err = -1, 1
    # Load the parameters and iterate each row
    for i in range(hpar.shape[1]):
        beg_cr = int(hpar[0][i])
        end_cr = int(hpar[1][i])
        if beg_cr <= t < end_cr:
            ssn = hpar[2][i]
            #V0          = Hpar[3][i]
            tilt_l = hpar[4][i]
            SmoothTiltL = hpar[12][i]
            #Bfield      = Hpar[6][i]
            polarity = hpar[7][i]
            solar_phase = hpar[8][i]
            nmcr = hpar[11][i]
            is_high_activity_period = (np.average([float(tilt) for tilt in hpar[4][i:i + 15]])) > 50
            k0, k0err = eval_k0(is_high_activity_period, polarity, q, solar_phase, tilt_l, nmcr, ssn)
            if debug:
                print(f"IsHighActivityPeriod {is_high_activity_period}")
                print(f"K0 {k0} +- {k0err * k0}")
            k0grid = np.linspace(k0 - 4 * k0err * k0, k0 + 4 * k0err * k0, num=nk0, endpoint=True)
            break
    return k0grid, k0, k0err

# %%
# EXECUTION FLOW
# Load simulation list
sim_list = load_simulation_list(APP, DEBUG)
# Load heliospheric parameters
hpar = Load_HeliosphericParameters(DEBUG)
len(sim_list), hpar.shape
# Out:
# Loading simulations for application: _FD006
# Parsed simulation: ['AMS-02Daily_20110801', 'Helium', 'Rigidity_AMS-02Daily_20110801_Helium.dat', '20110801', '20110801', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110801', 'Helium', 'Rigidity_AMS-02Daily_20110801_Helium.dat', '20110801', '20110801', '1', '0', '0']
# Added new ion type to OUTPUT_DICT: Helium
# Parsed simulation: ['AMS-02Daily_20110802', 'Helium', 'Rigidity_AMS-02Daily_20110802_Helium.dat', '20110802', '20110802', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110802', 'Helium', 'Rigidity_AMS-02Daily_20110802_Helium.dat', '20110802', '20110802', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110803', 'Helium', 'Rigidity_AMS-02Daily_20110803_Helium.dat', '20110803', '20110803', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110803', 'Helium', 'Rigidity_AMS-02Daily_20110803_Helium.dat', '20110803', '20110803', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110804', 'Helium', 'Rigidity_AMS-02Daily_20110804_Helium.dat', '20110804', '20110804', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110804', 'Helium', 'Rigidity_AMS-02Daily_20110804_Helium.dat', '20110804', '20110804', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110805', 'Helium', 'Rigidity_AMS-02Daily_20110805_Helium.dat', '20110805', '20110805', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110805', 'Helium', 'Rigidity_AMS-02Daily_20110805_Helium.dat', '20110805', '20110805', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110806', 'Helium', 'Rigidity_AMS-02Daily_20110806_Helium.dat', '20110806', '20110806', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110806', 'Helium', 'Rigidity_AMS-02Daily_20110806_Helium.dat', '20110806', '20110806', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110807', 'Helium', 'Rigidity_AMS-02Daily_20110807_Helium.dat', '20110807', '20110807', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110807', 'Helium', 'Rigidity_AMS-02Daily_20110807_Helium.dat', '20110807', '20110807', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110808', 'Helium', 'Rigidity_AMS-02Daily_20110808_Helium.dat', '20110808', '20110808', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110808', 'Helium', 'Rigidity_AMS-02Daily_20110808_Helium.dat', '20110808', '20110808', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110809', 'Helium', 'Rigidity_AMS-02Daily_20110809_Helium.dat', '20110809', '20110809', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110809', 'Helium', 'Rigidity_AMS-02Daily_20110809_Helium.dat', '20110809', '20110809', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110810', 'Helium', 'Rigidity_AMS-02Daily_20110810_Helium.dat', '20110810', '20110810', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110810', 'Helium', 'Rigidity_AMS-02Daily_20110810_Helium.dat', '20110810', '20110810', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110811', 'Helium', 'Rigidity_AMS-02Daily_20110811_Helium.dat', '20110811', '20110811', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110811', 'Helium', 'Rigidity_AMS-02Daily_20110811_Helium.dat', '20110811', '20110811', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110812', 'Helium', 'Rigidity_AMS-02Daily_20110812_Helium.dat', '20110812', '20110812', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110812', 'Helium', 'Rigidity_AMS-02Daily_20110812_Helium.dat', '20110812', '20110812', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110813', 'Helium', 'Rigidity_AMS-02Daily_20110813_Helium.dat', '20110813', '20110813', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110813', 'Helium', 'Rigidity_AMS-02Daily_20110813_Helium.dat', '20110813', '20110813', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110801', 'Proton', 'Rigidity_AMS-02Daily_20110801_Proton.dat', '20110801', '20110801', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110801', 'Proton', 'Rigidity_AMS-02Daily_20110801_Proton.dat', '20110801', '20110801', '1', '0', '0']
# Added new ion type to OUTPUT_DICT: Proton
# Parsed simulation: ['AMS-02Daily_20110802', 'Proton', 'Rigidity_AMS-02Daily_20110802_Proton.dat', '20110802', '20110802', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110802', 'Proton', 'Rigidity_AMS-02Daily_20110802_Proton.dat', '20110802', '20110802', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110803', 'Proton', 'Rigidity_AMS-02Daily_20110803_Proton.dat', '20110803', '20110803', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110803', 'Proton', 'Rigidity_AMS-02Daily_20110803_Proton.dat', '20110803', '20110803', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110804', 'Proton', 'Rigidity_AMS-02Daily_20110804_Proton.dat', '20110804', '20110804', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110804', 'Proton', 'Rigidity_AMS-02Daily_20110804_Proton.dat', '20110804', '20110804', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110805', 'Proton', 'Rigidity_AMS-02Daily_20110805_Proton.dat', '20110805', '20110805', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110805', 'Proton', 'Rigidity_AMS-02Daily_20110805_Proton.dat', '20110805', '20110805', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110806', 'Proton', 'Rigidity_AMS-02Daily_20110806_Proton.dat', '20110806', '20110806', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110806', 'Proton', 'Rigidity_AMS-02Daily_20110806_Proton.dat', '20110806', '20110806', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110807', 'Proton', 'Rigidity_AMS-02Daily_20110807_Proton.dat', '20110807', '20110807', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110807', 'Proton', 'Rigidity_AMS-02Daily_20110807_Proton.dat', '20110807', '20110807', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110808', 'Proton', 'Rigidity_AMS-02Daily_20110808_Proton.dat', '20110808', '20110808', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110808', 'Proton', 'Rigidity_AMS-02Daily_20110808_Proton.dat', '20110808', '20110808', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110809', 'Proton', 'Rigidity_AMS-02Daily_20110809_Proton.dat', '20110809', '20110809', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110809', 'Proton', 'Rigidity_AMS-02Daily_20110809_Proton.dat', '20110809', '20110809', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110810', 'Proton', 'Rigidity_AMS-02Daily_20110810_Proton.dat', '20110810', '20110810', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110810', 'Proton', 'Rigidity_AMS-02Daily_20110810_Proton.dat', '20110810', '20110810', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110811', 'Proton', 'Rigidity_AMS-02Daily_20110811_Proton.dat', '20110811', '20110811', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110811', 'Proton', 'Rigidity_AMS-02Daily_20110811_Proton.dat', '20110811', '20110811', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110812', 'Proton', 'Rigidity_AMS-02Daily_20110812_Proton.dat', '20110812', '20110812', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110812', 'Proton', 'Rigidity_AMS-02Daily_20110812_Proton.dat', '20110812', '20110812', '1', '0', '0']
# Parsed simulation: ['AMS-02Daily_20110813', 'Proton', 'Rigidity_AMS-02Daily_20110813_Proton.dat', '20110813', '20110813', '1', '0', '0']
# Adding simulation: ['AMS-02Daily_20110813', 'Proton', 'Rigidity_AMS-02Daily_20110813_Proton.dat', '20110813', '20110813', '1', '0', '0']
# Loaded simulation list:
# ['AMS-02Daily_20110801', 'Helium', 'Rigidity_AMS-02Daily_20110801_Helium.dat', '20110801', '20110801', '1', '0', '0']
# ['AMS-02Daily_20110802', 'Helium', 'Rigidity_AMS-02Daily_20110802_Helium.dat', '20110802', '20110802', '1', '0', '0']
# ['AMS-02Daily_20110803', 'Helium', 'Rigidity_AMS-02Daily_20110803_Helium.dat', '20110803', '20110803', '1', '0', '0']
# ['AMS-02Daily_20110804', 'Helium', 'Rigidity_AMS-02Daily_20110804_Helium.dat', '20110804', '20110804', '1', '0', '0']
# ['AMS-02Daily_20110805', 'Helium', 'Rigidity_AMS-02Daily_20110805_Helium.dat', '20110805', '20110805', '1', '0', '0']
# ['AMS-02Daily_20110806', 'Helium', 'Rigidity_AMS-02Daily_20110806_Helium.dat', '20110806', '20110806', '1', '0', '0']
# ['AMS-02Daily_20110807', 'Helium', 'Rigidity_AMS-02Daily_20110807_Helium.dat', '20110807', '20110807', '1', '0', '0']
# ['AMS-02Daily_20110808', 'Helium', 'Rigidity_AMS-02Daily_20110808_Helium.dat', '20110808', '20110808', '1', '0', '0']
# ['AMS-02Daily_20110809', 'Helium', 'Rigidity_AMS-02Daily_20110809_Helium.dat', '20110809', '20110809', '1', '0', '0']
# ['AMS-02Daily_20110810', 'Helium', 'Rigidity_AMS-02Daily_20110810_Helium.dat', '20110810', '20110810', '1', '0', '0']
# ['AMS-02Daily_20110811', 'Helium', 'Rigidity_AMS-02Daily_20110811_Helium.dat', '20110811', '20110811', '1', '0', '0']
# ['AMS-02Daily_20110812', 'Helium', 'Rigidity_AMS-02Daily_20110812_Helium.dat', '20110812', '20110812', '1', '0', '0']
# ['AMS-02Daily_20110813', 'Helium', 'Rigidity_AMS-02Daily_20110813_Helium.dat', '20110813', '20110813', '1', '0', '0']
# ['AMS-02Daily_20110801', 'Proton', 'Rigidity_AMS-02Daily_20110801_Proton.dat', '20110801', '20110801', '1', '0', '0']
# ['AMS-02Daily_20110802', 'Proton', 'Rigidity_AMS-02Daily_20110802_Proton.dat', '20110802', '20110802', '1', '0', '0']
# ['AMS-02Daily_20110803', 'Proton', 'Rigidity_AMS-02Daily_20110803_Proton.dat', '20110803', '20110803', '1', '0', '0']
# ['AMS-02Daily_20110804', 'Proton', 'Rigidity_AMS-02Daily_20110804_Proton.dat', '20110804', '20110804', '1', '0', '0']
# ['AMS-02Daily_20110805', 'Proton', 'Rigidity_AMS-02Daily_20110805_Proton.dat', '20110805', '20110805', '1', '0', '0']
# ['AMS-02Daily_20110806', 'Proton', 'Rigidity_AMS-02Daily_20110806_Proton.dat', '20110806', '20110806', '1', '0', '0']
# ['AMS-02Daily_20110807', 'Proton', 'Rigidity_AMS-02Daily_20110807_Proton.dat', '20110807', '20110807', '1', '0', '0']
# ['AMS-02Daily_20110808', 'Proton', 'Rigidity_AMS-02Daily_20110808_Proton.dat', '20110808', '20110808', '1', '0', '0']
# ['AMS-02Daily_20110809', 'Proton', 'Rigidity_AMS-02Daily_20110809_Proton.dat', '20110809', '20110809', '1', '0', '0']
# ['AMS-02Daily_20110810', 'Proton', 'Rigidity_AMS-02Daily_20110810_Proton.dat', '20110810', '20110810', '1', '0', '0']
# ['AMS-02Daily_20110811', 'Proton', 'Rigidity_AMS-02Daily_20110811_Proton.dat', '20110811', '20110811', '1', '0', '0']
# ['AMS-02Daily_20110812', 'Proton', 'Rigidity_AMS-02Daily_20110812_Proton.dat', '20110812', '20110812', '1', '0', '0']
# ['AMS-02Daily_20110813', 'Proton', 'Rigidity_AMS-02Daily_20110813_Proton.dat', '20110813', '20110813', '1', '0', '0']
# Ecluded simulations due to filter: 0
# Ecluded simulations due to particle type: 0
#  ----- HeliosphericParameters loaded ----
# (26, (17, 966))

# %%
el_sim_list = sim_list[0]
k0_arr, k0_ref, k0_ref_err = k0_grid(int(el_sim_list[3]), NK0, hpar, DEBUG)
k0_arr
# Out:
# array([0.00011179, 0.00011219, 0.00011259, 0.00011299, 0.0001134 ,
#        0.0001138 , 0.0001142 , 0.0001146 , 0.00011501, 0.00011541,
#        0.00011581, 0.00011621, 0.00011662, 0.00011702, 0.00011742,
#        0.00011782, 0.00011823, 0.00011863, 0.00011903, 0.00011943,
#        0.00011984, 0.00012024, 0.00012064, 0.00012104, 0.00012145,
#        0.00012185, 0.00012225, 0.00012265, 0.00012306, 0.00012346,
#        0.00012386, 0.00012426, 0.00012467, 0.00012507, 0.00012547,
#        0.00012587, 0.00012628, 0.00012668, 0.00012708, 0.00012748,
#        0.00012788, 0.00012829, 0.00012869, 0.00012909, 0.00012949,
#        0.0001299 , 0.0001303 , 0.0001307 , 0.0001311 , 0.00013151,
#        0.00013191, 0.00013231, 0.00013271, 0.00013312, 0.00013352,
#        0.00013392, 0.00013432, 0.00013473, 0.00013513, 0.00013553,
#        0.00013593, 0.00013634, 0.00013674, 0.00013714, 0.00013754,
#        0.00013795, 0.00013835, 0.00013875, 0.00013915, 0.00013956,
#        0.00013996, 0.00014036, 0.00014076, 0.00014117, 0.00014157,
#        0.00014197, 0.00014237, 0.00014278, 0.00014318, 0.00014358,
#        0.00014398, 0.00014438, 0.00014479, 0.00014519, 0.00014559,
#        0.00014599, 0.0001464 , 0.0001468 , 0.0001472 , 0.0001476 ,
#        0.00014801, 0.00014841, 0.00014881, 0.00014921, 0.00014962,
#        0.00015002, 0.00015042, 0.00015082, 0.00015123, 0.00015163,
#        0.00015203, 0.00015243, 0.00015284, 0.00015324, 0.00015364,
#        0.00015404, 0.00015445, 0.00015485, 0.00015525, 0.00015565,
#        0.00015606, 0.00015646, 0.00015686, 0.00015726, 0.00015767,
#        0.00015807, 0.00015847, 0.00015887, 0.00015928, 0.00015968,
#        0.00016008, 0.00016048, 0.00016089, 0.00016129, 0.00016169,
#        0.00016209, 0.00016249, 0.0001629 , 0.0001633 , 0.0001637 ,
#        0.0001641 , 0.00016451, 0.00016491, 0.00016531, 0.00016571,
#        0.00016612, 0.00016652, 0.00016692, 0.00016732, 0.00016773,
#        0.00016813, 0.00016853, 0.00016893, 0.00016934, 0.00016974,
#        0.00017014, 0.00017054, 0.00017095, 0.00017135, 0.00017175,
#        0.00017215, 0.00017256, 0.00017296, 0.00017336, 0.00017376,
#        0.00017417, 0.00017457, 0.00017497, 0.00017537, 0.00017578,
#        0.00017618, 0.00017658, 0.00017698, 0.00017739, 0.00017779,
#        0.00017819, 0.00017859, 0.00017899, 0.0001794 , 0.0001798 ,
#        0.0001802 , 0.0001806 , 0.00018101, 0.00018141, 0.00018181,
#        0.00018221, 0.00018262, 0.00018302, 0.00018342, 0.00018382,
#        0.00018423, 0.00018463, 0.00018503, 0.00018543, 0.00018584,
#        0.00018624, 0.00018664, 0.00018704, 0.00018745, 0.00018785,
#        0.00018825, 0.00018865, 0.00018906, 0.00018946, 0.00018986,
#        0.00019026, 0.00019067, 0.00019107, 0.00019147, 0.00019187,
#        0.00019228, 0.00019268, 0.00019308, 0.00019348, 0.00019389,
#        0.00019429, 0.00019469, 0.00019509, 0.00019549, 0.0001959 ,
#        0.0001963 , 0.0001967 , 0.0001971 , 0.00019751, 0.00019791,
#        0.00019831, 0.00019871, 0.00019912, 0.00019952, 0.00019992,
#        0.00020032, 0.00020073, 0.00020113, 0.00020153, 0.00020193,
#        0.00020234, 0.00020274, 0.00020314, 0.00020354, 0.00020395,
#        0.00020435, 0.00020475, 0.00020515, 0.00020556, 0.00020596,
#        0.00020636, 0.00020676, 0.00020717, 0.00020757, 0.00020797,
#        0.00020837, 0.00020878, 0.00020918, 0.00020958, 0.00020998,
#        0.00021039, 0.00021079, 0.00021119, 0.00021159, 0.000212  ,
#        0.0002124 , 0.0002128 , 0.0002132 , 0.0002136 , 0.00021401,
#        0.00021441, 0.00021481, 0.00021521, 0.00021562, 0.00021602,
#        0.00021642, 0.00021682, 0.00021723, 0.00021763, 0.00021803,
#        0.00021843, 0.00021884, 0.00021924, 0.00021964, 0.00022004,
#        0.00022045, 0.00022085, 0.00022125, 0.00022165, 0.00022206,
#        0.00022246, 0.00022286, 0.00022326, 0.00022367, 0.00022407,
#        0.00022447, 0.00022487, 0.00022528, 0.00022568, 0.00022608,
#        0.00022648, 0.00022689, 0.00022729, 0.00022769, 0.00022809,
#        0.0002285 , 0.0002289 , 0.0002293 , 0.0002297 , 0.0002301 ,
#        0.00023051, 0.00023091, 0.00023131, 0.00023171, 0.00023212,
#        0.00023252, 0.00023292, 0.00023332, 0.00023373, 0.00023413,
#        0.00023453, 0.00023493, 0.00023534, 0.00023574, 0.00023614,
#        0.00023654, 0.00023695, 0.00023735, 0.00023775, 0.00023815,
#        0.00023856, 0.00023896, 0.00023936, 0.00023976, 0.00024017,
#        0.00024057, 0.00024097, 0.00024137, 0.00024178, 0.00024218,
#        0.00024258, 0.00024298, 0.00024339, 0.00024379, 0.00024419,
#        0.00024459, 0.000245  , 0.0002454 , 0.0002458 , 0.0002462 ,
#        0.00024661, 0.00024701, 0.00024741, 0.00024781, 0.00024821,
#        0.00024862, 0.00024902, 0.00024942, 0.00024982, 0.00025023,
#        0.00025063, 0.00025103, 0.00025143, 0.00025184, 0.00025224,
#        0.00025264, 0.00025304, 0.00025345, 0.00025385, 0.00025425,
#        0.00025465, 0.00025506, 0.00025546, 0.00025586, 0.00025626,
#        0.00025667, 0.00025707, 0.00025747, 0.00025787, 0.00025828,
#        0.00025868, 0.00025908, 0.00025948, 0.00025989, 0.00026029,
#        0.00026069, 0.00026109, 0.0002615 , 0.0002619 , 0.0002623 ,
#        0.0002627 , 0.00026311, 0.00026351, 0.00026391, 0.00026431,
#        0.00026471, 0.00026512, 0.00026552, 0.00026592, 0.00026632,
#        0.00026673, 0.00026713, 0.00026753, 0.00026793, 0.00026834,
#        0.00026874, 0.00026914, 0.00026954, 0.00026995, 0.00027035,
#        0.00027075, 0.00027115, 0.00027156, 0.00027196, 0.00027236])

# %%
file_name = f"DataTXT/{el_sim_list[2]}"
x_exp, f_exp, er_exp_inf, er_exp_sup = np.loadtxt(file_name, unpack=True, usecols=(0, 1, 2, 3))
valid_indices = (x_exp >= 3) & (x_exp <= 11)
x_exp, f_exp = x_exp[valid_indices], f_exp[valid_indices]
er_exp_inf, er_exp_sup = er_exp_inf[valid_indices], er_exp_sup[valid_indices]
initialize_output_dict([el_sim_list], x_exp, f_exp, er_exp_inf, er_exp_sup, k0_ref, k0_ref_err, debug=DEBUG)
# Out:
# Processing simulation for ion: Helium, date: 2011-08-01
# Processing rigidity value: 3.13
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 3.13
# Initialized data for ion: Helium, rigidity: 3.13, date: 2011-08-01
# Processing rigidity value: 3.46
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 3.46
# Initialized data for ion: Helium, rigidity: 3.46, date: 2011-08-01
# Processing rigidity value: 3.83
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 3.83
# Initialized data for ion: Helium, rigidity: 3.83, date: 2011-08-01
# Processing rigidity value: 4.22
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 4.22
# Initialized data for ion: Helium, rigidity: 4.22, date: 2011-08-01
# Processing rigidity value: 4.65
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 4.65
# Initialized data for ion: Helium, rigidity: 4.65, date: 2011-08-01
# Processing rigidity value: 5.12
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 5.12
# Initialized data for ion: Helium, rigidity: 5.12, date: 2011-08-01
# Processing rigidity value: 5.63
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 5.63
# Initialized data for ion: Helium, rigidity: 5.63, date: 2011-08-01
# Processing rigidity value: 6.19
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 6.19
# Initialized data for ion: Helium, rigidity: 6.19, date: 2011-08-01
# Processing rigidity value: 6.78
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 6.78
# Initialized data for ion: Helium, rigidity: 6.78, date: 2011-08-01
# Processing rigidity value: 7.42
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 7.42
# Initialized data for ion: Helium, rigidity: 7.42, date: 2011-08-01
# Processing rigidity value: 8.12
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 8.12
# Initialized data for ion: Helium, rigidity: 8.12, date: 2011-08-01
# Processing rigidity value: 8.87
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 8.87
# Initialized data for ion: Helium, rigidity: 8.87, date: 2011-08-01
# Processing rigidity value: 9.68
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 9.68
# Initialized data for ion: Helium, rigidity: 9.68, date: 2011-08-01
# Processing rigidity value: 10.6
# Initialized OUTPUT_DICT for ion: Helium, rigidity: 10.6
# Initialized data for ion: Helium, rigidity: 10.6, date: 2011-08-01
# Final OUTPUT_DICT:
# Ion: Helium, Data: {np.float64(3.13): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(46.49), 'ErExp_inf': np.float64(0.715052), 'ErExp_sup': np.float64(0.715052), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(3.46): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(39.97), 'ErExp_inf': np.float64(0.60208), 'ErExp_sup': np.float64(0.60208), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(3.83): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(33.98), 'ErExp_inf': np.float64(0.49679), 'ErExp_sup': np.float64(0.49679), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(4.22): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(28.41), 'ErExp_inf': np.float64(0.418688), 'ErExp_sup': np.float64(0.418688), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(4.65): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(23.47), 'ErExp_inf': np.float64(0.348281), 'ErExp_sup': np.float64(0.348281), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(5.12): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(19.92), 'ErExp_inf': np.float64(0.292062), 'ErExp_sup': np.float64(0.292062), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(5.63): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(16.52), 'ErExp_inf': np.float64(0.242074), 'ErExp_sup': np.float64(0.242074), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(6.19): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(13.28), 'ErExp_inf': np.float64(0.198494), 'ErExp_sup': np.float64(0.198494), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(6.78): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(11.03), 'ErExp_inf': np.float64(0.170294), 'ErExp_sup': np.float64(0.170294), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(7.42): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(9.117), 'ErExp_inf': np.float64(0.137768), 'ErExp_sup': np.float64(0.137768), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(8.12): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(7.311), 'ErExp_inf': np.float64(0.112699), 'ErExp_sup': np.float64(0.112699), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(8.87): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.fl ...
# Ion: Proton, Data: {}

# %%
sim_name, ions, file_name, init_date, final_date, radius, latitude, longitude = el_sim_list
ions = [i.strip() for i in ions.split(',')]
ions_str = '_'.join(ions)
is_tko = "Rigidity" not in file_name
start_dir = os.getcwd()

start_dir
os.path.join(start_dir, f"{sim_name}_{ions_str}")
# Out:
# '/Users/stark/Development/Research/Cosmica-dev/extra/Simulations_K0Search/AMS-02Daily_20110801_Helium'

# %%
for el_sim_list in sim_list[:1]:
    print(f"Processing {el_sim_list[0]} {el_sim_list[1]}...")

    # Create grid of K0 values to simulate
    k0_arr, k0_ref, k0_ref_err = griglia_valori_k0(el_sim_list[3], NK0, hpar, DEBUG)
    if DEBUG:
        print(f"Generated K0 grid: {k0_arr}, reference K0: {k0_ref}, reference K0 error: {k0_ref_err}")

    # Load experimental data and initialize output dictionary
    file_name = f"DataTXT/{el_sim_list[2]}"
    x_exp, f_exp, er_exp_inf, er_exp_sup = np.loadtxt(file_name, unpack=True, usecols=(0, 1, 2, 3))
    valid_indices = (x_exp >= 3) & (x_exp <= 11)
    x_exp, f_exp = x_exp[valid_indices], f_exp[valid_indices]
    er_exp_inf, er_exp_sup = er_exp_inf[valid_indices], er_exp_sup[valid_indices]
    if DEBUG:
        print(f"Loaded experimental data from {file_name}")

    initialize_output_dict([el_sim_list], x_exp, f_exp, er_exp_inf, er_exp_sup, k0_ref, k0_ref_err, debug=DEBUG)

    # Submit simulations and wait for results
    output_dir_path, output_file_list = SubmitSims(el_sim_list, k0_arr, R_range=[3, 11])

    if DEBUG:
        print(f"Submitted simulations, output directory: {output_dir_path}, output files: {output_file_list}")

    wait_for_files(f"{output_dir_path}/outfile/*.dat", len(output_file_list), SLEEP_TIME, DEBUG)
    if DEBUG:
        print(f"All simulation files are ready in {output_dir_path}/outfile/")

    # Process results of simulations
    raw_matrix_sims = GetRawMatrix(output_dir_path, output_file_list, DEBUG)
    process_simulations(el_sim_list, raw_matrix_sims, x_exp, debug=DEBUG)

    # Cleanup output directory
    if output_dir_path and 'Simulations_K0Search' in output_dir_path:
        print(f"Removing directory {output_dir_path}.")
        shutil.rmtree(output_dir_path)

# Save results to file Result{APP}.pkl using pickle
with open(f"Result{APP}.pkl", "wb") as f:
    pickle.dump(OUTPUT_DICT, f, protocol=pickle.HIGHEST_PROTOCOL)
print(f"Results saved to Result{APP}.pkl")
# Out:
# Processing AMS-02Daily_20110801 Helium...
# Generated K0 grid: [0.00011179 0.00011219 0.00011259 0.00011299 0.0001134  0.0001138
#  0.0001142  0.0001146  0.00011501 0.00011541 0.00011581 0.00011621
#  0.00011662 0.00011702 0.00011742 0.00011782 0.00011823 0.00011863
#  0.00011903 0.00011943 0.00011984 0.00012024 0.00012064 0.00012104
#  0.00012145 0.00012185 0.00012225 0.00012265 0.00012306 0.00012346
#  0.00012386 0.00012426 0.00012467 0.00012507 0.00012547 0.00012587
#  0.00012628 0.00012668 0.00012708 0.00012748 0.00012788 0.00012829
#  0.00012869 0.00012909 0.00012949 0.0001299  0.0001303  0.0001307
#  0.0001311  0.00013151 0.00013191 0.00013231 0.00013271 0.00013312
#  0.00013352 0.00013392 0.00013432 0.00013473 0.00013513 0.00013553
#  0.00013593 0.00013634 0.00013674 0.00013714 0.00013754 0.00013795
#  0.00013835 0.00013875 0.00013915 0.00013956 0.00013996 0.00014036
#  0.00014076 0.00014117 0.00014157 0.00014197 0.00014237 0.00014278
#  0.00014318 0.00014358 0.00014398 0.00014438 0.00014479 0.00014519
#  0.00014559 0.00014599 0.0001464  0.0001468  0.0001472  0.0001476
#  0.00014801 0.00014841 0.00014881 0.00014921 0.00014962 0.00015002
#  0.00015042 0.00015082 0.00015123 0.00015163 0.00015203 0.00015243
#  0.00015284 0.00015324 0.00015364 0.00015404 0.00015445 0.00015485
#  0.00015525 0.00015565 0.00015606 0.00015646 0.00015686 0.00015726
#  0.00015767 0.00015807 0.00015847 0.00015887 0.00015928 0.00015968
#  0.00016008 0.00016048 0.00016089 0.00016129 0.00016169 0.00016209
#  0.00016249 0.0001629  0.0001633  0.0001637  0.0001641  0.00016451
#  0.00016491 0.00016531 0.00016571 0.00016612 0.00016652 0.00016692
#  0.00016732 0.00016773 0.00016813 0.00016853 0.00016893 0.00016934
#  0.00016974 0.00017014 0.00017054 0.00017095 0.00017135 0.00017175
#  0.00017215 0.00017256 0.00017296 0.00017336 0.00017376 0.00017417
#  0.00017457 0.00017497 0.00017537 0.00017578 0.00017618 0.00017658
#  0.00017698 0.00017739 0.00017779 0.00017819 0.00017859 0.00017899
#  0.0001794  0.0001798  0.0001802  0.0001806  0.00018101 0.00018141
#  0.00018181 0.00018221 0.00018262 0.00018302 0.00018342 0.00018382
#  0.00018423 0.00018463 0.00018503 0.00018543 0.00018584 0.00018624
#  0.00018664 0.00018704 0.00018745 0.00018785 0.00018825 0.00018865
#  0.00018906 0.00018946 0.00018986 0.00019026 0.00019067 0.00019107
#  0.00019147 0.00019187 0.00019228 0.00019268 0.00019308 0.00019348
#  0.00019389 0.00019429 0.00019469 0.00019509 0.00019549 0.0001959
#  0.0001963  0.0001967  0.0001971  0.00019751 0.00019791 0.00019831
#  0.00019871 0.00019912 0.00019952 0.00019992 0.00020032 0.00020073
#  0.00020113 0.00020153 0.00020193 0.00020234 0.00020274 0.00020314
#  0.00020354 0.00020395 0.00020435 0.00020475 0.00020515 0.00020556
#  0.00020596 0.00020636 0.00020676 0.00020717 0.00020757 0.00020797
#  0.00020837 0.00020878 0.00020918 0.00020958 0.00020998 0.00021039
#  0.00021079 0.00021119 0.00021159 0.000212   0.0002124  0.0002128
#  0.0002132  0.0002136  0.00021401 0.00021441 0.00021481 0.00021521
#  0.00021562 0.00021602 0.00021642 0.00021682 0.00021723 0.00021763
#  0.00021803 0.00021843 0.00021884 0.00021924 0.00021964 0.00022004
#  0.00022045 0.00022085 0.00022125 0.00022165 0.00022206 0.00022246
#  0.00022286 0.00022326 0.00022367 0.00022407 0.00022447 0.00022487
#  0.00022528 0.00022568 0.00022608 0.00022648 0.00022689 0.00022729
#  0.00022769 0.00022809 0.0002285  0.0002289  0.0002293  0.0002297
#  0.0002301  0.00023051 0.00023091 0.00023131 0.00023171 0.00023212
#  0.00023252 0.00023292 0.00023332 0.00023373 0.00023413 0.00023453
#  0.00023493 0.00023534 0.00023574 0.00023614 0.00023654 0.00023695
#  0.00023735 0.00023775 0.00023815 0.00023856 0.00023896 0.00023936
#  0.00023976 0.00024017 0.00024057 0.00024097 0.00024137 0.00024178
#  0.00024218 0.00024258 0.00024298 0.00024339 0.00024379 0.00024419
#  0.00024459 0.000245   0.0002454  0.0002458  0.0002462  0.00024661
#  0.00024701 0.00024741 0.00024781 0.00024821 0.00024862 0.00024902
#  0.00024942 0.00024982 0.00025023 0.00025063 0.00025103 0.00025143
#  0.00025184 0.00025224 0.00025264 0.00025304 0.00025345 0.00025385
#  0.00025425 0.00025465 0.00025506 0.00025546 0.00025586 0.00025626
#  0.00025667 0.00025707 0.00025747 0.00025787 0.00025828 0.00025868
#  0.00025908 0.00025948 0.00025989 0.00026029 0.00026069 0.00026109
#  0.0002615  0.0002619  0.0002623  0.0002627  0.00026311 0.00026351
#  0.00026391 0.00026431 0.00026471 0.00026512 0.00026552 0.00026592
#  0.00026632 0.00026673 0.00026713 0.00026753 0.00026793 0.00026834
#  0.00026874 0.00026914 0.00026954 0.00026995 0.00027035 0.00027075
#  0.00027115 0.00027156 0.00027196 0.00027236], reference K0: 0.00019207424690793413, reference K0 error: 0.1045
# Loaded experimental data from DataTXT/Rigidity_AMS-02Daily_20110801_Helium.dat
# Processing simulation for ion: Helium, date: 2011-08-01
# Processing rigidity value: 3.13
# Initialized data for ion: Helium, rigidity: 3.13, date: 2011-08-01
# Processing rigidity value: 3.46
# Initialized data for ion: Helium, rigidity: 3.46, date: 2011-08-01
# Processing rigidity value: 3.83
# Initialized data for ion: Helium, rigidity: 3.83, date: 2011-08-01
# Processing rigidity value: 4.22
# Initialized data for ion: Helium, rigidity: 4.22, date: 2011-08-01
# Processing rigidity value: 4.65
# Initialized data for ion: Helium, rigidity: 4.65, date: 2011-08-01
# Processing rigidity value: 5.12
# Initialized data for ion: Helium, rigidity: 5.12, date: 2011-08-01
# Processing rigidity value: 5.63
# Initialized data for ion: Helium, rigidity: 5.63, date: 2011-08-01
# Processing rigidity value: 6.19
# Initialized data for ion: Helium, rigidity: 6.19, date: 2011-08-01
# Processing rigidity value: 6.78
# Initialized data for ion: Helium, rigidity: 6.78, date: 2011-08-01
# Processing rigidity value: 7.42
# Initialized data for ion: Helium, rigidity: 7.42, date: 2011-08-01
# Processing rigidity value: 8.12
# Initialized data for ion: Helium, rigidity: 8.12, date: 2011-08-01
# Processing rigidity value: 8.87
# Initialized data for ion: Helium, rigidity: 8.87, date: 2011-08-01
# Processing rigidity value: 9.68
# Initialized data for ion: Helium, rigidity: 9.68, date: 2011-08-01
# Processing rigidity value: 10.6
# Initialized data for ion: Helium, rigidity: 10.6, date: 2011-08-01
# Final OUTPUT_DICT:
# Ion: Helium, Data: {np.float64(3.13): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(46.49), 'ErExp_inf': np.float64(0.715052), 'ErExp_sup': np.float64(0.715052), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(3.46): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(39.97), 'ErExp_inf': np.float64(0.60208), 'ErExp_sup': np.float64(0.60208), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(3.83): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(33.98), 'ErExp_inf': np.float64(0.49679), 'ErExp_sup': np.float64(0.49679), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(4.22): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(28.41), 'ErExp_inf': np.float64(0.418688), 'ErExp_sup': np.float64(0.418688), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(4.65): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(23.47), 'ErExp_inf': np.float64(0.348281), 'ErExp_sup': np.float64(0.348281), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(5.12): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(19.92), 'ErExp_inf': np.float64(0.292062), 'ErExp_sup': np.float64(0.292062), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(5.63): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(16.52), 'ErExp_inf': np.float64(0.242074), 'ErExp_sup': np.float64(0.242074), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(6.19): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(13.28), 'ErExp_inf': np.float64(0.198494), 'ErExp_sup': np.float64(0.198494), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(6.78): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(11.03), 'ErExp_inf': np.float64(0.170294), 'ErExp_sup': np.float64(0.170294), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(7.42): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(9.117), 'ErExp_inf': np.float64(0.137768), 'ErExp_sup': np.float64(0.137768), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(8.12): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.float64(7.311), 'ErExp_inf': np.float64(0.112699), 'ErExp_sup': np.float64(0.112699), 'K0ref': np.float64(0.00019207424690793413), 'K0Err_ref': np.float64(2.0071758801879117e-05)}}, np.float64(8.87): {datetime.date(2011, 8, 1): {'diffBest': 9e+99, 'K0best': 0, 'K0Min': 9e+99, 'K0Max': 0, 'Fluxbest': 0, 'FluxMin': 9e+99, 'FluxMax': 0, 'fExp': np.fl ...
# Ion: Proton, Data: {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 21
#      18 initialize_output_dict([el_sim_list], x_exp, f_exp, er_exp_inf, er_exp_sup, k0_ref, k0_ref_err, debug=DEBUG)
#      20 # Submit simulations and wait for results
# ---> 21 output_dir_path, output_file_list = SubmitSims(el_sim_list, k0_arr, R_range=[3, 11])
#      23 if DEBUG:
#      24     print(f"Submitted simulations, output directory: {output_dir_path}, output files: {output_file_list}")
#
# File ~/Development/Research/Cosmica-dev/extra/Simulations_K0Search/JobCreation.py:399, in SubmitSims(simulation_list, k0_array, R_range, debug)
#     396 os.makedirs(input_dir_path, exist_ok=True)
#     398 # Generate input and output file names for the simulation
# --> 399 input_file_list, output_file_list = CreateInputFile(
#     400     k0_array,
#     401     heliospheric_parameters,
#     402     R_range,
#     403     input_dir_path,
#     404     sim_name,
#     405     ions,
#     406     os.path.join(start_dir, "DataTXT", file_name.strip()),
#     407     init_date,
#     408     final_date,
#     409     [radius],
#     410     [latitude],
#     411     [longitude]
#     412 )
#     414 if input_file_list:
#     415     # If there are input files, prepare and run the simulation
#     416     CreateRun(
#     417         input_dir_path,
#     418         f"{sim_name}_{ions_str}{'_TKO' if is_tko else ''}",
#     419         EXE_full_path,
#     420         input_file_list,
#     421     )
#
# File ~/Development/Research/Cosmica-dev/extra/Simulations_K0Search/JobCreation.py:141, in CreateInputFile(k0vals, HeliosphericParameters, R_range, InputDirPATH, SimName, Ions, FileName, InitDate, FinalDate, rad, lat, lon, DEBUG)
#     138 if DEBUG: print(f"K0 to be simulated {k0valstr}")
#     139 for Ion in Ions:
#     140   # - ottieni la lista degli isotopi da simulare
# --> 141   IsotopesList=findKey(Ion,Isotopes_dict)
#     142   if DEBUG: print(IsotopesList)
#     143   if len(IsotopesList)<=0:
#
# File _pydevd_bundle/pydevd_cython_darwin_312_64.pyx:1187, in _pydevd_bundle.pydevd_cython_darwin_312_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_312_64.pyx:627, in _pydevd_bundle.pydevd_cython_darwin_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_312_64.pyx:937, in _pydevd_bundle.pydevd_cython_darwin_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_312_64.pyx:928, in _pydevd_bundle.pydevd_cython_darwin_312_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_312_64.pyx:585, in _pydevd_bundle.pydevd_cython_darwin_312_64.PyDBFrame.do_wait_suspend()
#
# File ~/Applications/PyCharm Professional Edition.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py:1220, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1217         from_this_thread.append(frame_id)
#    1219 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1220     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File ~/Applications/PyCharm Professional Edition.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py:1235, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1232             self._call_mpl_hook()
#    1234         self.process_internal_commands()
# -> 1235         time.sleep(0.01)
#    1237 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1239 # process any stepping instructions
#
# KeyboardInterrupt:
